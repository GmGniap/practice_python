# %%
import pandas as pd

# %%
df = pd.read_xml("test.xml")
print(df)
# Out:
#       MartusBulletinExportFormatVersion  PublicAndPrivateData  \
# 0                                   3.0                   NaN
# 1                                   NaN                   NaN
# 2                                   NaN                   NaN
# 3                                   NaN                   NaN
# 4                                   NaN                   NaN
# ...                                 ...                   ...
# 1748                                NaN                   NaN
# 1749                                NaN                   NaN
# 1750                                NaN                   NaN
# 1751                                NaN                   NaN
# 1752                                NaN                   NaN
#
#       BulletinMetaData  MainFieldSpecs  PrivateFieldSpecs  FieldValues
# 0                  NaN             NaN                NaN          NaN
# 1                  NaN             NaN                NaN          NaN
# ...

# %%
print(df.dtypes)
# Out:
# MartusBulletinExportFormatVersion    float64
# PublicAndPrivateData                 float64
# BulletinMetaData                     float64
# MainFieldSpecs                       float64
# PrivateFieldSpecs                    float64
# FieldValues                          float64
# dtype: object

# %%
df['FieldValues'].to_list()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...
