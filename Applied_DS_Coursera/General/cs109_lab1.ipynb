# %%
# Import Library HERE 
import pandas as pd
import numpy as np

# %%
# Start writing code here...
# Import with Numpy , Pandas 
data = pd.read_csv("goodread.csv", header=None, names=["rating", "review_count", "isbn", "booktype", "author_url", "year", "genre_urls", "dir", "rating_count", "name"])
data.head(10)
# Out:
#    rating review_count        isbn         booktype  \
# 0    4.40       136455  0439023483  good_reads:book
# 1    4.41        16648  0439358078  good_reads:book
# 2    3.56        85746  0316015849  good_reads:book
# 3    4.23        47906  0061120081  good_reads:book
# 4    4.23        34772  0679783261  good_reads:book
# 5    4.25        12363  0446675539  good_reads:book
# 6    4.22         7205  0066238501  good_reads:book
# 7    4.38        10902  0060256656  good_reads:book
# 8    3.79        20670  0452284244  good_reads:book
# 9    4.18        12302  0345391802  good_reads:book
#
#                                           author_url    year  \
# 0  https://www.goodreads.com/author/show/153394.S...  2008.0
# 1  https://www.goodreads.com/author/show/1077326....  2003.0
# 2  https://www.goodreads.com/author/show/941441.S...  2005.0
# 3  https://www.goodreads.com/author/show/1825.Har...  1960.0
# 4  https://www.goodreads.com/author/show/1265.Jan...  1813.0
# ...

# %%
# Basics 
data.dtypes
data.shape
print(data.shape[0]) #row
print(data.shape[1]) #column
data.columns
# Out:
# 6000
# 10
# Index(['rating', 'review_count', 'isbn', 'booktype', 'author_url', 'year',
#        'genre_urls', 'dir', 'rating_count', 'name'],
#       dtype='object')

# %%
data[data.rating < 3.5]
# Out:
#       rating review_count        isbn         booktype  \
# 89      3.40         7564  0142437247  good_reads:book
# 109     3.32         8099  0142437263  good_reads:book
# 140     3.44        43943  0143038419  good_reads:book
# 164     3.38         6393  1892295490  good_reads:book
# 167     3.46         2016  0140424385  good_reads:book
# ...      ...          ...         ...              ...
# 5958    3.29         2951  0452281423  good_reads:book
# 5964    3.41          663         NaN  good_reads:book
# 5979    2.77          800  0060988649  good_reads:book
# 5981    3.36         1693  0312424442  good_reads:book
# 5989    3.36          192  842534607X  good_reads:book
#
#                                              author_url    year  \
# 89    https://www.goodreads.com/author/show/1624.Her...  1851.0
# 109   https://www.goodreads.com/author/show/7799.Nat...  1850.0
# 140   https://www.goodreads.com/author/show/11679.El...  2000.0
# ...

# %%
# be careful the usage of brackets - wrong > () , correct - []
data.name[data.rating < 3]
# Out:
# 2609                How To Be A Perfect Girl
# 3738    Revealing Eden (Save the Pearls, #1)
# 5844                              Mein Kampf
# 5979                                    Lost
# Name: name, dtype: object

# %%
cout = np.sum(data.rating<3.5)
print(cout)
out = cout / data.shape[0]  # it doesn't give 0 in Python 3 , but will give Zero output in Python 2 because the denominator must be float type in Python 2
print(out)
#print(type(data.shape[0]))
# Out:
# 120
# 0.02

# %%
data.rating.mean() , data.rating.std() # Mean / Standard Deviation 
data.rating.max()
data[(data.year > 2000) & (data.rating==5)]
# data[(data.year < 0) & (data.rating>4)] # Multiple condition with AND
# Out:
#       rating review_count        isbn         booktype  \
# 1718     5.0           28         NaN  good_reads:book
# 2145     5.0            3  1300589469  good_reads:book
# 2903     5.0            0  0983002282  good_reads:book
# 2909     5.0            0  0983002215  good_reads:book
# 4473     5.0            0         NaN  good_reads:book
# 5564     5.0            9         NaN  good_reads:book
# 5692     5.0            0         NaN  good_reads:book
#
#                                              author_url    year  \
# 1718  https://www.goodreads.com/author/show/6467808....  2014.0
# 2145  https://www.goodreads.com/author/show/6906561....  2012.0
# 2903  https://www.goodreads.com/author/show/6589034....  2012.0
# 2909  https://www.goodreads.com/author/show/6589034....  2011.0
# 4473  https://www.goodreads.com/author/show/6896621....  2012.0
# 5564  https://www.goodreads.com/author/show/7738947....  2014.0
# 5692  https://www.goodreads.com/author/show/5989528....  2012.0
#
# ...

# %%
#np.sum([(data.year > 2000) & (data.rating>4)]) # Try to count 
data.dtypes
# Out:
# rating          float64
# review_count     object
# isbn             object
# booktype         object
# author_url       object
# year            float64
# genre_urls       object
# dir              object
# rating_count     object
# name             object
# dtype: object

# %%
# Change 'review_count' , 'rating_count' , 'year' - data type into integer 
#data.head(n=5)
# data['rating_count'] = data.rating_count.astype(int)
data[data.year.isnull()]
# data[data.review_count.isnull()]
# Out:
#       rating review_count        isbn         booktype  \
# 2442    4.23          526         NaN  good_reads:book
# 2869    4.61            2         NaN  good_reads:book
# 3643     NaN         None        None             None
# 5282     NaN         None        None             None
# 5572    3.71           35  8423336603  good_reads:book
# 5658    4.32           44         NaN  good_reads:book
# 5683    4.56          204         NaN  good_reads:book
#
#                                              author_url  year  \
# 2442  https://www.goodreads.com/author/show/623606.A...   NaN
# 2869  https://www.goodreads.com/author/show/8182217....   NaN
# 3643                                               None   NaN
# 5282                                               None   NaN
# 5572  https://www.goodreads.com/author/show/285658.E...   NaN
# 5658  https://www.goodreads.com/author/show/25307.Ro...   NaN
# 5683  https://www.goodreads.com/author/show/3097905....   NaN
#
# ...

# %%
data[data.year.isnull()]

# %%
# data.rating_count.fillna(value=np.nan, inplace=True) Not working
#data['rating_count'].replace("None", np.nan, inplace=True)
data['review_count'].replace("None", value= np.nan, inplace=True)

# %%
# data[data.review_count.notnull()]
data.where(data['rating']<3).dropna()
#print(data[data['rating']<3])
#year_null = data[data.year.isnull()]
#review_null = data[data.review_count.isnull()]
#print(year_null.shape)
# Out:
#       rating review_count        isbn         booktype  \
# 3738    2.00          368  0983650322  good_reads:book
# 5844    2.97         1399  0395083621  good_reads:book
# 5979    2.77          800  0060988649  good_reads:book
#
#                                              author_url    year  \
# 3738  https://www.goodreads.com/author/show/9414.Vic...  2011.0
# 5844  https://www.goodreads.com/author/show/30691.Ad...  1925.0
# 5979  https://www.goodreads.com/author/show/7025.Gre...  2001.0
#
#                                              genre_urls  \
# 3738  /genres/young-adult|/genres/science-fiction|/g...
# 5844  /genres/history|/genres/non-fiction|/genres/bi...
# 5979  /genres/fantasy|/genres/fiction|/genres/myster...
#
#                                      dir rating_count  \
# 3738  dir38/12393909-revealing-eden.html          688
# 5844         dir59/54270.Mein_Kampf.html        12417
# 5979               dir60/24929.Lost.html        11128
#
# ...

# %%
df = data[data.year.notnull()]
df.shape
df.columns
#print(year_not_null.shape)
#df = data[data.review_count.notnull()]
#print(review_not_null.shape)
# Out:
# Index(['rating', 'review_count', 'isbn', 'booktype', 'author_url', 'year',
#        'genre_urls', 'dir', 'rating_count', 'name'],
#       dtype='object')

# %%
df['review_count'] = df.review_count.astype(int)
print(data.dtypes)
# Out:
# rating          float64
# review_count     object
# isbn             object
# booktype         object
# author_url       object
# year            float64
# genre_urls       object
# dir              object
# rating_count     object
# name             object
# dtype: object
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df = pd.DataFrame(np.arange(12).reshape(3,4),columns=['A','B','C','D'])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.drop(['B','C'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-983096100db8> in <module>
# ----> 1 df.drop(['B','C'])
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.drop('B')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-6dabbbd007ea> in <module>
# ----> 1 df.drop('B')
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
# ...
